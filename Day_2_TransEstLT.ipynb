# %% [markdown]
# <a href="https://colab.research.google.com/github/rahulvigneswaran/100DaysOfDeepLearning/blob/main/Day_2_TransEstLT.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Transferability Estimation for Long Tailed Recognition
#
# <blockquote class="twitter-tweet"><p lang="en" dir="ltr">🥁 Day 2: Transferability Estimation for Long Tailed Recognition<br><br>One way to tackle LT is to transfer features from head to tail classes. Can we use Transferability Estimation (TE) in order to better facilitate that?<a href="https://twitter.com/hashtag/100DaysOfDeepLearning?src=hash&amp;ref_src=twsrc%5Etfw">#100DaysOfDeepLearning</a></p>&mdash; Rahul Vigneswaran (@lettucelemontea) <a href="https://twitter.com/lettucelemontea/status/1501450769601802240?ref_src=twsrc%5Etfw">March 9, 2022</a></blockquote> <script async src="https://platform.twitter.com/widgets.js" charset="utf-8"></script>
#
# https://twitter.com/lettucelemontea/status/1501450769601802240?s=20&t=VGrhcCo37r_kw3cjG0AcvQ

# %%
# !git clone <I will make this repo pubic soon>
# Out:
# Cloning into 'LibLongTail'...
# remote: Enumerating objects: 310, done.
# remote: Counting objects: 100% (310/310), done.
# remote: Compressing objects: 100% (181/181), done.
# remote: Total 310 (delta 162), reused 269 (delta 121), pack-reused 0
# Receiving objects: 100% (310/310), 70.49 MiB | 22.87 MiB/s, done.
# Resolving deltas: 100% (162/162), done.

# %%
# !pip install -r LibLongTail/requirements.txt
# Out:
# ...
#      |████████████████████████████████| 527 kB 1.2 MB/s
# ...
#      |██████████████████████████████▎ | 834.1 MB 1.4 MB/s eta 0:00:33tcmalloc: large alloc 1147494400 bytes == 0x5573016e6000 @  0x7f88a8913615 0x5572c7e4e3bc 0x5572c7f2f18a 0x5572c7e511cd 0x5572c7f43b3d 0x5572c7ec5458 0x5572c7ec002f 0x5572c7e52aba 0x5572c7ec52c0 0x5572c7ec002f 0x5572c7e52aba 0x5572c7ec1cd4 0x5572c7f44986 0x5572c7ec1350 0x5572c7f44986 0x5572c7ec1350 0x5572c7f44986 0x5572c7ec1350 0x5572c7e52f19 0x5572c7e96a79 0x5572c7e51b32 0x5572c7ec51dd 0x5572c7ec002f 0x5572c7e52aba 0x5572c7ec1cd4 0x5572c7ec002f 0x5572c7e52aba 0x5572c7ec0eae 0x5572c7e529da 0x5572c7ec1108 0x5572c7ec002f
#      |████████████████████████████████| 881.9 MB 1.9 kB/s
# ...
#      |████████████████████████████████| 23.2 MB 1.5 MB/s
# ...
#      |████████████████████████████████| 1.7 MB 38.0 MB/s
# ...
#      |████████████████████████████████| 397 kB 10.3 MB/s
# ...
#      |████████████████████████████████| 952 kB 36.6 MB/s
# ...

# %%
# %cd LibLongTail/
# Out:
# /content/LibLongTail

# %%
# !git clone https://github.com/thuml/LogME
# Out:
# Cloning into 'LogME'...
# remote: Enumerating objects: 97, done.
# remote: Counting objects: 100% (97/97), done.
# remote: Compressing objects: 100% (69/69), done.
# remote: Total 97 (delta 48), reused 71 (delta 28), pack-reused 0
# Unpacking objects: 100% (97/97), done.

# %%
import wandb
wandb.login()
# Out:
# wandb: Appending key for api.wandb.ai to your netrc file: /root/.netrc
# True

# %%
# !python run.py --sub_exp "etlt_all_class" --cfg "/content/LibLongTail/configs/classification/CIFAR100LT/ce.yaml" --opts LOGGER.PROJECT_NAME "100DaysOfDL" GENERAL.EPOCH 100 GENERAL.GPUS [0] ARCH.BACKBONE "resnet18" DATASET.IMB 0.005 GENERAL.METHOD "etlt"
# Out:
# Global seed set to 1
# Using downloaded and verified file: datasets/CIFAR100_LT/val.pth
# Using downloaded and verified file: datasets/CIFAR100_LT/test.pth
# Using downloaded and verified file: datasets/CIFAR100_LT/train_imb_200.pth
# Files already downloaded and verified
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Global seed set to 1
# initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# Files already downloaded and verified
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %%
# !python run.py --sub_exp "etlt_low_classes_fast" --cfg "/content/LibLongTail/configs/classification/CIFAR100LT/ce.yaml" --opts LOGGER.PROJECT_NAME "100DaysOfDL" GENERAL.EPOCH 100 GENERAL.GPUS [0] ARCH.BACKBONE "resnet18" DATASET.IMB 0.005 GENERAL.METHOD "etlt"
# Out:
# Global seed set to 1
# Using downloaded and verified file: datasets/CIFAR100_LT/val.pth
# Using downloaded and verified file: datasets/CIFAR100_LT/test.pth
# Using downloaded and verified file: datasets/CIFAR100_LT/train_imb_200.pth
# Files already downloaded and verified
# Using 16bit native Automatic Mixed Precision (AMP)
# GPU available: True, used: True
# TPU available: False, using: 0 TPU cores
# IPU available: False, using: 0 IPUs
# Global seed set to 1
# initializing distributed: GLOBAL_RANK: 0, MEMBER: 1/1
# ----------------------------------------------------------------------------------------------------
# distributed_backend=nccl
# All distributed processes registered. Starting with 1 processes
# ----------------------------------------------------------------------------------------------------
#
# Files already downloaded and verified
# Files already downloaded and verified
# LOCAL_RANK: 0 - CUDA_VISIBLE_DEVICES: [0]
# ...

# %% [markdown]
# |Method|Accuracy|Many|Mid|Low|
# |--------|---------|---------|-------|------|
# |CE|0.214|0.453|0.2353|0.0597|
# |cRT|0.2526|0.458|0.2873|0.1075|
# |ETLT (All Classes) | 0.2166|0.4588|0.2339|0.0615|
# |ETLT (Low Classes) | 0.1905|0.4223|0.1956|0.0502|
